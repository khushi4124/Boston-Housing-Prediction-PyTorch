# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/BostonHousingData.csv")

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df.shape
# Out:
# (506, 14)

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# std     27.999513    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.175000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     76.800000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.975000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  486.000000  506.000000
# mean    12.715432   22.532806
# std      7.155871    9.197104
# min      1.730000    5.000000
# 25%      7.125000   17.025000
# 50%     11.430000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %% [markdown]
# # **UNIVARIATE ANALYSIS**

# %% [markdown]
# UNIVARIATE ANALYSIS OF CRIM

# %%
df['CRIM'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['CRIM'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['CRIM'].skew()
# Out:
# np.float64(5.2128426499800975)

# %%
df['CRIM']=df['CRIM'].fillna(df['CRIM'].median())

# %%
#log transformation as the distribution is right skewed
df['CRIM']=np.log1p(df['CRIM'])

# %%
df['CRIM'].skew()
# Out:
# np.float64(1.3630981113986196)

# %%
df['CRIM'].plot(kind='box')
# Out:
# <Axes: >

# %%
#checking if the outliers actually exist or not
df[df['CRIM']>3.4]
# Out:
#          CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 380  4.499545  0.0   18.1   0.0  0.671  6.968   91.9  1.4165   24  666
# 398  3.672542  0.0   18.1   0.0  0.693  5.453  100.0  1.4896   24  666
# 404  3.750191  0.0   18.1   0.0  0.693  5.531   85.4  1.6074   24  666
# 405  4.232958  0.0   18.1   0.0  0.693  5.683  100.0  1.4254   24  666
# 410  3.953852  0.0   18.1   0.0  0.597  5.757  100.0  1.4130   24  666
# 414  3.844731  0.0   18.1   0.0  0.693  4.519  100.0  1.6582   24  666
# 418  4.311257  0.0   18.1   0.0  0.679  5.957  100.0  1.8026   24  666
# 427  3.654855  NaN   18.1   0.0  0.679  6.202   78.7  1.8629   24  666
#
#      PTRATIO       B  LSTAT  MEDV
# 380     20.2  396.90  17.21  10.4
# 398     20.2  396.90  30.59   5.0
# 404     20.2  329.46  27.38   8.5
# 405     20.2  384.97  22.98   5.0
# 410     20.2    2.60  10.11  15.0
# 414     20.2   88.27  36.98   7.0
# 418     20.2   16.45  20.62   8.8
# 427     20.2   18.82  14.52  10.9

# %% [markdown]
# UNIVARIATE ANALYSIS OF ZN

# %%
df['ZN'].isnull().sum()
# Out:
# np.int64(20)

# %%
df['ZN']=df['ZN'].fillna(df['ZN'].median())

# %%
df['ZN'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['ZN'].skew()
# Out:
# np.float64(2.3246025026357247)

# %%
#log transformation as the distribution is right skewed
df['ZN']=np.log1p(df['ZN'])

# %%
#skewness after transformation
df['ZN'].skew()
# Out:
# np.float64(1.292990478914116)

# %% [markdown]
# UNIVARIATE ANALYSIS OF INDUS

# %%
df['INDUS'].isnull().sum()
# Out:
# np.int64(20)

# %%
df['INDUS'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['INDUS'].skew()
# Out:
# np.float64(0.30372218758107833)

# %%
df['INDUS']=df['INDUS'].fillna(df['INDUS'].median())

# %%
df['INDUS'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# UNIVARIATE ANALYSIS OF CHAS

# %%
df['CHAS'].isnull().sum()
# Out:
# np.int64(20)

# %%
df['CHAS'].value_counts()
# Out:
# CHAS
# 0.0    452
# 1.0     34
# Name: count, dtype: int64

# %%
df['CHAS']=df['CHAS'].fillna(df['CHAS'].median())

# %%
df['CHAS'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# UNIVARIATE ANALYSIS OF NOX

# %%
df['NOX'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['NOX'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['NOX'].skew()
# Out:
# np.float64(0.7293079225348787)

# %%
df['NOX'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# UNIVARIATE ANALYSIS OF RM

# %%
df['RM'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['RM'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['RM'].skew()
# Out:
# np.float64(0.40361213328874385)

# %%
df['RM'].plot(kind='box')
# Out:
# <Axes: >

# %%
#checking if the outliers are actually there or not
df[df['RM']>7.5]
# Out:
#          CRIM        ZN  INDUS  CHAS     NOX     RM   AGE     DIS  RA
# Out:
#          CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 365  1.714855  0.0  18.10   0.0  0.718  3.561   87.9  1.6132   24  666
# 367  2.675679  0.0  18.10   0.0  0.631  3.863  100.0  1.5106   24  666
# 374  2.970322  0.0  18.10   0.0  0.668  4.138  100.0  1.1370   24  666
# 384  3.048557  0.0  18.10   0.0  0.700  4.368   91.2  1.4395   24  666
# 386  3.234505  0.0  18.10   0.0  0.700  4.652  100.0  1.4672   24  666
# 406  3.078059  0.0   9.69   0.0  0.659  4.138  100.0  1.1781   24  666
# 412  2.986237  0.0  18.10   0.0  0.597  4.628  100.0  1.5539   24  666
# 414  3.844731  0.0  18.10   0.0  0.693  4.519  100.0  1.6582   24  666
#
#      PTRATIO       B  LSTAT  MEDV
# 365     20.2  354.70   7.12  27.5
# 367     20.2  131.42  13.33  23.1
# 374     20.2  396.90  37.97  13.8
# 384     20.2  285.83  30.63   8.8
# 386     20.2  396.90  28.28  10.5
# 406     20.2  370.22  23.34  11.9
# 412     20.2   28.79  34.37  17.9
# 414     20.2   88.27  36.98   7.0

# %% [markdown]
# UNIVARIATE ANALYSIS OF AGE

# %%
df['AGE'].isnull().sum()
# Out:
# np.int64(20)

# %%
df['AGE']=df['AGE'].fillna(df['AGE'].median())

# %%
df['AGE'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['AGE'].skew()
# Out:
# np.float64(-0.6259679565444078)

# %%
df['AGE'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# UNIVARIATE ANALYSIS OF DIS

# %%
df['DIS'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['DIS'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['DIS'].skew()
# Out:
# np.float64(1.0117805793009007)

# %%
#log transformation as the distriibution is right skewed
df['DIS']=np.log1p(df['DIS'])

# %%
#skewness after the log transformation
df['DIS'].skew()
# Out:
# np.float64(0.33156144277059646)

# %%
df['DIS'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# UNIVARIATE ANALYSIS OF RAD

# %%
df['RAD'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['RAD'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['RAD'].skew()
# Out:
# np.float64(1.0048146482182057)

# %%
#log transformation as the distribution is right skewed
df['RAD']=np.log1p(df['RAD'])

# %%
#skewness after the transformation
df['RAD'].skew()
# Out:
# np.float64(0.5327599614480961)

# %%
df['RAD'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# UNIVARIATE ANALYSIS OF TAX

# %%
df['TAX'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['TAX'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['TAX'].skew()
# Out:
# np.float64(0.669955941795016)

# %%
df['TAX'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# UNIVARIATE ANALYSIS OF PTRATIO

# %%
df['PTRATIO'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['PTRATIO'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['PTRATIO'].skew()
# Out:
# np.float64(-0.8023249268537809)

# %%
df['PTRATIO'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# UNIVARIATE ANALYSIS OF B

# %%
df['B'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['B'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['B'].skew()
# Out:
# np.float64(-2.8903737121414492)

# %%
#left skewed distribution so applying reflect + log transformation
df['B']=np.log1p(df['B'].max()+1-df['B'])

# %%
#skewness after the transformation
df['B'].skew()
# Out:
# np.float64(0.8652558331681142)

# %%
df['B'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# UNIVARIATE ANALYSIS OF LSTAT

# %%
df['LSTAT'].isnull().sum()
# Out:
# np.int64(20)

# %%
df['LSTAT'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['LSTAT'].skew()
# Out:
# np.float64(0.908891836957813)

# %%
df['LSTAT']=df['LSTAT'].fillna(df['LSTAT'].median())

# %%
df['LSTAT'].skew()
# Out:
# np.float64(0.9470796835302951)

# %%
#slightly right skewed distribution, so applying log transformation
df['LSTAT']=np.log1p(df['LSTAT'])

# %%
#skewness after transformation
df['LSTAT'].skew()
# Out:
# np.float64(-0.21295716373415788)

# %%
df['LSTAT'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# UNIVARIATE ANALYSIS OF MEDV

# %%
df['MEDV'].isnull().sum()
# no need of further analysis as this is the target variable
# Out:
# np.int64(0)

# %% [markdown]
# X AND Y

# %%
#creating input features dataset/dataframe
X=df.drop(columns=['MEDV'])

# %%
X
# Out:
#          CRIM        ZN  INDUS  CHAS    NOX     RM   AGE       DIS       RAD  \
# 0    0.006300  2.944439   2.31   0.0  0.538  6.575  65.2  1.627278  0.693147
# 1    0.026944  0.000000   7.07   0.0  0.469  6.421  78.9  1.786261  1.098612
# 2    0.026924  0.000000   7.07   0.0  0.469  7.185  61.1  1.786261  1.098612
# 3    0.031857  0.000000   2.18   0.0  0.458  6.998  45.8  1.954757  1.386294
# 4    0.066770  0.000000   2.18   0.0  0.458  7.147  54.2  1.954757  1.386294
# ..        ...       ...    ...   ...    ...    ...   ...       ...       ...
# 501  0.060747  0.000000  11.93   0.0  0.573  6.593  69.1  1.246630  0.693147
# 502  0.044275  0.000000  11.93   0.0  0.573  6.120  76.7  1.190127  0.693147
# 503  0.058986  0.000000  11.93   0.0  0.573  6.976  91.0  1.152943  0.693147
# 504  0.103991  0.000000  11.93   0.0  0.573  6.794  89.3  1.220505  0.693147
# 505  0.046320  0.000000  11.93   0.0  0.573  6.030  76.8  1.254191  0.693147
#
#      TAX  PTRATIO         B     LSTAT
# 0    296     15.3  0.693147  1.788421
# 1    242     17.8  0.693147  2.316488
# 2    242     17.8  1.803359  1.615420
# 3    222     18.7  1.451614  1.371181
# 4    222     18.7  0.693147  2.520113
# ..   ...      ...       ...       ...
# 501  273     21.0  1.932970  2.520113
# 502  273     21.0  0.693147  2.310553
# 503  273     21.0  0.693147  1.893112
# 504  273     21.0  1.695616  2.012233
# 505  273     21.0  0.693147  2.183802
#
# [506 rows x 13 columns]

# %%
#creating target dataset/dataframe
Y=df['MEDV']

# %%
Y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %% [markdown]
# USING PYTORCH TO BUILD OUR MODEL

# %%
import torch
import torch.nn as nn

# %%
import torch.optim as optim

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
X_train, X_test, Y_train, Y_test=train_test_split(X_scaled,Y,test_size=0.2,random_state=42)

# %%
X_train_tensor=torch.tensor(X_train, dtype=torch.float32)
Y_train_tensor=torch.tensor(Y_train.values, dtype=torch.float32).view(-1,1)
Y_test_tensor=torch.tensor(Y_test.values, dtype=torch.float32).view(-1,1)
X_test_tensor=torch.tensor(X_test, dtype=torch.float32)

# %%
class LinearRegression(nn.Module):
  def __init__(self,in_features,out_features):
    super().__init__()
    self.layer1=nn.Linear(in_features,32)
    self.dropout=nn.Dropout(0.2)     #randomly zeroes 20 neurons to prevent overfitting
    self.relu=nn.ReLU()   #activation function to introduce non linearity
    self.layer2=nn.Linear(32,out_features)
  def forward(self,X_train_tensor):
    X_train_tensor=self.layer1(X_train_tensor)
    X_train_tensor=self.dropout(X_train_tensor)
    X_train_tensor=self.relu(X_train_tensor)
    X_train_tensor=self.layer2(X_train_tensor)
    return X_train_tensor

# %%
model=LinearRegression(in_features=13,out_features=1)
print(model)
# Out:
# LinearRegression(
#   (layer1): Linear(in_features=13, out_features=32, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (relu): ReLU()
#   (layer2): Linear(in_features=32, out_features=1, bias=True)
# )

# %%
learning_rate=0.01
optimizer=optim.Adam(model.parameters(),lr=learning_rate)
lossfunction=nn.MSELoss()

# %%
epochs=1000
for epoch in range(epochs):
  y_predicted=model(X_train_tensor)
  loss=lossfunction(y_predicted,Y_train_tensor)
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()
  if (epoch%100==0):
    print(f"epoch {epoch}, loss {loss}")
print(f"epoch 1000, loss {loss}")
# Out:
# epoch 0, loss 608.1071166992188
# epoch 100, loss 39.79365921020508
# epoch 200, loss 22.184778213500977
# epoch 300, loss 17.53192710876465
# epoch 400, loss 19.70732879638672
# epoch 500, loss 16.543615341186523
# epoch 600, loss 15.595383644104004
# epoch 700, loss 15.511754989624023
# epoch 800, loss 15.5722017288208
# epoch 900, loss 15.272289276123047
# epoch 1000, loss 13.716986656188965

# %%
#testing
model.eval()
with torch.no_grad():
  output=model(X_test_tensor)
  loss=lossfunction(output,Y_test_tensor)
  print(f"loss {loss}")
#since overall training loss ~ test loss, the model did not overfit and was able to generalize the data
# Out:
# loss 14.914104461669922
